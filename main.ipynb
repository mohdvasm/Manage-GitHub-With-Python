# %%
repos_to_delete = [
    # "mohdvasm/100-days-of-machine-learning",
    "mohdvasm/Advanced-RAG-Tutorials",
    # "mohdvasm/agents-course",
    "mohdvasm/ai-engineering-hub",
    "mohdvasm/aie-book",
    "mohdvasm/automatic-number-plate-recognition-python-yolov8",
    "mohdvasm/best-low-level-design-resources",
    "mohdvasm/Build-a-Large-Language-Model-from-Scratch",
    "mohdvasm/cayman-blog",
    # "mohdvasm/Centralized-repository-shipping_calculations",
    "mohdvasm/cnn-explainer",
    # "mohdvasm/Complete-Data-Science-With-Machine-Learning-And-NLP-2024",
    # "mohdvasm/Complete-Python-Bootcamp",
    # "mohdvasm/computer-vision-course",
    "mohdvasm/coursera-deep-learning-specialization",
    "mohdvasm/Data-Science-Interview-Questions-Answers",
    "mohdvasm/deep-learning-interview-questions",
    # "mohdvasm/dl-fundamentals",
    # "mohdvasm/dsa-using-python",
    "mohdvasm/EDA-Feature-engineering",
    "mohdvasm/embedchain",
    "mohdvasm/Feature-Engineering",
    "mohdvasm/Finetuning-LLM-KN",
    "mohdvasm/generative-ai-for-beginners",
    "mohdvasm/Generative-AI-Indepth-Basic-to-Advance",
    "mohdvasm/Generative-AI-Mastery-Resources",
    "mohdvasm/Generative-AI-with-LLMs-Lab",
    "mohdvasm/generative-ai-with-llms-notes",
    "mohdvasm/gitbook",
    # "mohdvasm/gpt-dev-bigram",
    "mohdvasm/gradio-groq-basics",
    # "mohdvasm/Grokking-Machine-Learning-",
    # "mohdvasm/Hands-On-Large-Language-Models",
    "mohdvasm/Hands-On-LLM-Fine-Tuning",
    # "mohdvasm/huggingface-llama-recipes",
    # "mohdvasm/ineuron-data-science-interview-preparation",
    "mohdvasm/interview-help-codebasics",
    # "mohdvasm/Jupyter-Setup",
    "mohdvasm/langchain",
    "mohdvasm/langchain-academy",
    "mohdvasm/LargeLanguageModelsProjects",
    "mohdvasm/llm-course",
    "mohdvasm/llm-datasets",
    # "mohdvasm/LLM-workshop-2024",
    # "mohdvasm/LLMs-from-scratch",
    # "mohdvasm/LLMs-in-Production-Manning",
    "mohdvasm/llms-interview-questions",
    # "mohdvasm/machine-learning-book-pytorch",
    "mohdvasm/Mathematics-for-Machine-Learning-and-Data-Science-Specialization",
    "mohdvasm/Mathematics-for-Machine-Learning-and-Data-Science-Specialization-by-DeepLearning.AI",
    "mohdvasm/Mathematics-for-Machine-Learning-and-Data-Science-Specialization-Coursera",
    "mohdvasm/MLOps-Basics",
    # "mohdvasm/mlproject-tut",
    "mohdvasm/MLQuestions",
    # "mohdvasm/oaqjp-final-project-emb-ai",
    "mohdvasm/openai-cookbook",
    # "mohdvasm/OpenCV",
    "mohdvasm/Play-with-LLMs",
    "mohdvasm/poole",
    # "mohdvasm/practical-statistics-for-data-scientists",
    # "mohdvasm/Problem-Solving-in-Data-Structures-Algorithms-using-Python",
    # "mohdvasm/profile",
    # "mohdvasm/pytorch-deep-learning",
    "mohdvasm/pytorch-fundamentals-microsoft",
    "mohdvasm/pytorch-paligemma",
    "mohdvasm/Pytorch-Tutorial",
    "mohdvasm/rag-zero-to-hero-guide",
    "mohdvasm/RAG_Techniques",
    "mohdvasm/RetrievalTutorials",
    "mohdvasm/roboflow-notebooks",
    "mohdvasm/seemore-vlm-from-scratch",
    # "mohdvasm/smol-course",
    "mohdvasm/smol-vision",
]

# %%
forked_repos = [
    # "mohdvasm/100-days-of-machine-learning",
    # # "mohdvasm/agents-course",
    # "mohdvasm/Centralized-repository-shipping_calculations",
    # "mohdvasm/Complete-Data-Science-With-Machine-Learning-And-NLP-2024",
    # "mohdvasm/Complete-Python-Bootcamp",
    # "mohdvasm/computer-vision-course",
    # "mohdvasm/dl-fundamentals",
    # "mohdvasm/dsa-using-python",
    # "mohdvasm/gpt-dev-bigram",
    # "mohdvasm/Grokking-Machine-Learning-",
    # "mohdvasm/Hands-On-Large-Language-Models",
    # "mohdvasm/huggingface-llama-recipes",
    # "mohdvasm/ineuron-data-science-interview-preparation",
    # "mohdvasm/Jupyter-Setup",
    # "mohdvasm/LLM-workshop-2024",
    # "mohdvasm/LLMs-from-scratch",
    # "mohdvasm/LLMs-in-Production-Manning",
    # "mohdvasm/machine-learning-book-pytorch",
    # "mohdvasm/mlproject-tut",
    # "mohdvasm/oaqjp-final-project-emb-ai",
    # "mohdvasm/OpenCV",
    # "mohdvasm/practical-statistics-for-data-scientists",
    # "mohdvasm/Problem-Solving-in-Data-Structures-Algorithms-using-Python",
    # "mohdvasm/profile",
    # "mohdvasm/pytorch-deep-learning",
    # "mohdvasm/smol-course",
    "mohdvasm/Statistics-Books",
    # "mohdvasm/tensorflow-deep-learning",
    "mohdvasm/TensorflowKeras-ReinforcementLearning",
    # "mohdvasm/The-Grand-Complete-Data-Science-Materials",
    "mohdvasm/the-incredible-pytorch",
    "mohdvasm/The-Ultimate-C-Programming-Course",
    "mohdvasm/theLMbook",
    "mohdvasm/Transformers-Materials-KN",
    "mohdvasm/unsloth",
    "mohdvasm/VGGnet-face-recognition",
    "mohdvasm/vlms-zero-to-hero",
]

# %%
len(forked_repos)
# Out:
# 37
